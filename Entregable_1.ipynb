# %%
#Importacion de librerias
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
#Cargamso el archivo desde el equipo 
df=pd.read_excel("Detalle precios y productos fabricados 2022.xlsx")
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 3             OMAR RODRIGUEZ GOMEZ   1.0        TP0001
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# ...

# %%
#Se verifica la informacion del Data Frame 
df.info()
#Se imprimen los primeros 5 registros del data frame 
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1423 non-null   object
#  1   FECHA_DOC                  1423 non-null   datetime64[ns]
#  2   NOMBRE_VENDEDOR            1424 non-null   object
#  3   NOMBRE_CLIENTE             1424 non-null   object
#  4   CANT                       1419 non-null   float64
#  5   CVE_ART                    1424 non-null   object
#  6   DESCR                      1424 non-null   object
#  7   PRECIO_UNITARIO            1424 non-null   float64
#  8   COSTO_UNITARIO             1422 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1424 non-null   float64
#  10  SUBTOTAL_PARTIDA           1422 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto 
filtro1 = df[df['NOMBRE_CLIENTE']=='ANA BARBARA CRUZ PALACIOS']
filtro1

#Se ha seleccionado la variable del nombre de cleinte para poder 
#analizar todas las compras que ha hecho un cliente en especifico
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ  ANA BARBARA CRUZ PALACIOS
# 33    F37092 2022-01-11   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 34    F37092 2022-01-11   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 71    F37161 2022-01-21   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 119   F37257 2022-02-01   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 120   F37257 2022-02-01   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 188   F37415 2022-02-18  LETICIA RAMIREZ HERNANDEZ  ANA BARBARA CRUZ PALACIOS
# 189   F37415 2022-02-18  LETICIA RAMIREZ HERNANDEZ  ANA BARBARA CRUZ PALACIOS
# 200   F37436 2022-02-22  LETICIA RAMIREZ HERNANDEZ  ANA BARBARA CRUZ PALACIOS
# 309   F37620 2022-03-14   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# ...

# %%
#Filtrado por filas 
filtro2 = filtro1.iloc[0:5,]
filtro2
#Con este filtro obtenemos las primeras 5 compras del cliente del filtro 1
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2   F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 7   F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ  ANA BARBARA CRUZ PALACIOS
# 33  F37092 2022-01-11   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 34  F37092 2022-01-11   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 71  F37161 2022-01-21   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
#
#     CANT       CVE_ART                                     DESCR  \
# 2    7.0        TP0007      TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT
# 7    3.0        TP0001      TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT
# 33  10.0  PJ31A1F1A400   TER J 3/16"ØX1" EXT.2MTS MALLA Z/ESPADA
# 34  10.0  PK31A1F1A400    TER K 3/16"ØX1" EXT.2MT RES/MALLA INOX
# 71  10.0  PK31B1I1A000  TER K 3/16"ØX1 1/2" EXT.7MT MALLA Z/ESPA
#
#     PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# ...

# %%
#Filtro por columnas 
filtro3 = filtro2.iloc[:,[3,4,6,13]]
filtro3
#Con este filtro podemos obtener un resumen mas especifico de las compras 
#y poder observar las unidades y el margen total de ganancia
# Out:
#                NOMBRE_CLIENTE  CANT                                     DESCR  \
# 2   ANA BARBARA CRUZ PALACIOS   7.0      TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT
# 7   ANA BARBARA CRUZ PALACIOS   3.0      TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT
# 33  ANA BARBARA CRUZ PALACIOS  10.0   TER J 3/16"ØX1" EXT.2MTS MALLA Z/ESPADA
# 34  ANA BARBARA CRUZ PALACIOS  10.0    TER K 3/16"ØX1" EXT.2MT RES/MALLA INOX
# 71  ANA BARBARA CRUZ PALACIOS  10.0  TER K 3/16"ØX1 1/2" EXT.7MT MALLA Z/ESPA
#
#     MARGEN_TOTAL_CALCULADO
# 2                  2617.56
# 7                   166.62
# 33                  815.55
# 34                 1376.36
# 71                 3103.83

# %%
#Filtrado de Filas vs Columnas 
#Creamos un nuevo Data Frame para poder hacer la comparacion 
df1 = pd.read_excel("Detalle precios y productos fabricados 2022.xlsx")
df1
#Ahora podemos aplicar el filtro de comparacion para 2 clientes 
filtro4 = df1.loc[]
filtro4
# Out:
# 0         381.68
# 1         936.87
# 2        2617.56
# 3         101.04
# 4         141.41
#           ...
# 1421     3658.12
# 1422     3683.48
# 1423     4757.41
# 1424     4025.49
# 1425    13253.45
# Name: MARGEN_TOTAL_CALCULADO, Length: 1426, dtype: float64
